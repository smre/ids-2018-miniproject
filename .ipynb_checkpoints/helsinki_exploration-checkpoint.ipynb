# %%
import osmnx as ox
import geopandas as gp
from geopy.geocoders.osm import Nominatim
from shapely.geometry import Point, Polygon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

buildings = ox.buildings_from_place("Helsinki, Finland")
buildings.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-29cb139fdab7> in <module>()
# ----> 1 import osmnx as ox
#       2 import geopandas as gp
#       3 from geopy.geocoders.osm import Nominatim
#       4 from shapely.geometry import Point, Polygon
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'osmnx'

# %% [raw]
# buildings

# %%
buildings.columns
# Out:
# Index(['3dr:height1', '3dr:type', 'FIXME', 'FIXME:levels', 'FIXMEoperator',
#        'abandoned:amenity', 'access', 'addr:city', 'addr:country',
#        'addr:flats',
#        ...
#        'wheelchair', 'wheelchair:description', 'wholesale', 'wifi', 'wikidata',
#        'wikipedia', 'wikipedia:en', 'year', 'year_on', 'year_on:approximate'],
#       dtype='object', length=500)

# %%
buildings[buildings['description'].notnull()]['description']
# Out:
# 13780270                                       Vesivoimalaitos
# 14099216                                           huoltoasema
# 14462165                                        Puutavarahalli
# 14462317                                     Planmecan varasto
# 14462332                                         Starkin halli
# 14463220                                        autonpesuhalli
# 14580703                                  Ratsupoliisien talli
# 15802490                                             pukukopit
# 16085371                                        entinen Elanto
# 21286362     Merkkihuoltovaltuudet: - Mercedes-Benz - Volks...
# 22904565                                           parkkihalli
# 22969372                                            Autopesula
# 23174782     Wholesale in e.g. parfyms and cosmetics. Estab...
# 23174786                                           kivinavetta
# 24406503           Kehitysvammaisten nuorten elämävalmennusta.
# 24764695     Vihitty käyttöön 28. toukokuuta 1905, raittius...
# 24904305     Entinen Elanto (Siwa), jonka paistouunista tul...
# 26379241                                            Punatiiltä
# 26379244                                            Punatiiltä
# 26379253                                                Tiiltä
# 26379264                                            rantasauna
# 26379269                                                 Puuta
# 26471491                                         Autismisäätiö
# 26936195                                              venevaja
# 26936322                                        huoltorakennus
# 27148889                      ravintola, pukuhuoneet ja saunat
# 27520027                                                  lato
# 27520036                             Ponitallin tallirakennus.
# 27597591                                       omistusasuntoja
# 29853165     Vanha Malmin asemarakennus, asemakäytössä aina...
#                                    ...
# 88760134     Karjalaisten kesäkoti Villa Bergsund, kesäisin...
# 91666231     Hietaniemi cemetery old chapel designed by The...
# 93771384                                Hiekkasiilon ajoportti
# 97385370                  Japanin suurlähettilään virka-asunto
# 97385377                   Iranin suurlähettilään virka-asunto
# 117131825                                            pukukoppi
# 130742303                            Kaupungin vuokra-asuntoja
# 130742304                    Vapaarahoitteisia omistuasuntoja.
# 139225504      Sörnäisten metroaseman eteläinen hätäuloskäynti
# 165548714                                     katettu sisäpiha
# 176990437                                    Tiilinen muuntaja
# 207149992                Viikinmäen energiatunnelin pystykuilu
# 227213547                                      Vanha vesitorni
# 232284746                                           Kirpputori
# 232743300                         Hanasaaren B-voimalan piippu
# 232743301    The lowest part of the chimney is wider, taper...
# 298620792    Kiosk serves coffee, Italian ice-cream and fin...
# 344156055                               Länsimetron pystykuilu
# 344156056                               Länsimetron pystykuilu
# 361868764                                             Jätetila
# 361869633                                             Jätetila
# 396387351                                       Asiakaspalvelu
# 443717280         Allas Sea Pool\nhttps://www.allasseapool.fi/
# 450084239                               Länsimetron pystykuilu
# 481688641                               Länsimetron pystykuilu
# 481688642                               Länsimetron pystykuilu
# 484524284    Jallukka, musiikkialan vuokratalo, Elävän musi...
# 561441466                Connection between Biomedicum 1 and 2
# 563033904                                   Metallisepän paja.
# 567458454                                             Muuntaja
# Name: description, Length: 86, dtype: object

# %%
buildings[buildings['amenity'].notnull()]['amenity']
# Out:
# 6189301        public_building
# 6269033        social_facility
# 8034126                theatre
# 8041428                 clinic
# 8097296                 school
# 8597256       place_of_worship
# 10528156            veterinary
# 13779794                clinic
# 13859034       social_facility
# 14437628                school
# 14437817          kindergarten
# 14437989      place_of_worship
# 14463220              car_wash
# 14463247             fast_food
# 14463902          fire_station
# 14831236               parking
# 15090769          leikkipuisto
# 15090778      place_of_worship
# 15216881      place_of_worship
# 15242906            restaurant
# 15242921      place_of_worship
# 15242942     conference_centre
# 15802367      place_of_worship
# 15802445          kindergarten
# 15802447             childcare
# 15802647               parking
# 15920017            university
# 15920021            university
# 16083419                school
# 16085371          kindergarten
#                    ...
# 577745374       waste_disposal
# 577745389       waste_disposal
# 577760775       waste_disposal
# 578146379         kindergarten
# 580103807       waste_disposal
# 580112879       waste_disposal
# 580181118       waste_disposal
# 580277688       waste_disposal
# 580277689       waste_disposal
# 580377735       waste_disposal
# 580377736       waste_disposal
# 580377737       waste_disposal
# 580514055       waste_disposal
# 580516134       waste_disposal
# 580516135       waste_disposal
# 584114356       waste_disposal
# 584114366       waste_disposal
# 584880153       waste_disposal
# 586432494      bicycle_parking
# 587141520       waste_disposal
# 588431772       waste_disposal
# 588431773       waste_disposal
# 588863742       waste_disposal
# 596316390       waste_disposal
# 596937289              library
# 605555505       waste_disposal
# 606942611       waste_disposal
# 606942612       waste_disposal
# 621758868      bicycle_parking
# 625576876           restaurant
# Name: amenity, Length: 819, dtype: object

# %%
buildings[buildings['amenity'] == 'restaurant']
# Out:
#           3dr:height1 3dr:type FIXME FIXME:levels FIXMEoperator  \
# 15242906          NaN      NaN   NaN          NaN           NaN
# 17038654          NaN      NaN   NaN          NaN           NaN
# 17039604          NaN      NaN   NaN          NaN           NaN
# 23815666          NaN      NaN   NaN          NaN           NaN
# 24904043          NaN      NaN   NaN          NaN           NaN
# 26257345          NaN      NaN   NaN          NaN           NaN
# 26936530          NaN      NaN   NaN          NaN           NaN
# 28739860          NaN      NaN   NaN          NaN           NaN
# 31785988          NaN      NaN   NaN          NaN           NaN
# 34714712          NaN      NaN   NaN          NaN           NaN
# 44490860          NaN      NaN   NaN          NaN           NaN
# 44923563          NaN      NaN   NaN          NaN           NaN
# 64297889          NaN      NaN   NaN          NaN           NaN
# 88732590          NaN      NaN   NaN          NaN           NaN
# 93983220          NaN      NaN   NaN          NaN           NaN
# 115475357         NaN      NaN   NaN          NaN           NaN
# 115475359         NaN      NaN   NaN          NaN           NaN
# 156128272         NaN      NaN   NaN          NaN           NaN
# 170507937         NaN      NaN   NaN          NaN           NaN
# 332438355         NaN      NaN   NaN          NaN           NaN
# 446178807         NaN      NaN   NaN          NaN           NaN
# 494775391         NaN      NaN   NaN          NaN           NaN
# 559139564         NaN      NaN   NaN          NaN           NaN
# 625576876         NaN      NaN   NaN          NaN           NaN
#
#           abandoned:amenity access addr:city addr:country addr:flats  \
# 15242906                NaN    NaN  Helsinki           FI        NaN
# 17038654                NaN    NaN  helsinki          NaN        NaN
# 17039604                NaN    NaN       NaN          NaN        NaN
# 23815666                NaN    NaN  Helsinki          NaN        NaN
# 24904043                NaN    NaN       NaN          NaN        NaN
# 26257345                NaN    NaN       NaN          NaN        NaN
# 26936530                NaN    NaN       NaN          NaN        NaN
# 28739860                NaN    NaN  Helsinki          NaN        NaN
# 31785988                NaN    NaN  Helsinki          NaN        NaN
# 34714712                NaN    NaN       NaN          NaN        NaN
# 44490860                NaN    NaN       NaN          NaN        NaN
# 44923563                NaN    NaN       NaN          NaN        NaN
# 64297889                NaN    NaN       NaN          NaN        NaN
# 88732590                NaN    NaN  Helsinki          NaN        NaN
# 93983220                NaN    NaN  Helsinki          NaN        NaN
# 115475357               NaN    NaN  Helsinki          NaN        NaN
# 115475359               NaN    NaN  Helsinki          NaN        NaN
# 156128272               NaN    NaN       NaN          NaN        NaN
# 170507937               NaN    NaN  Helsinki          NaN        NaN
# 332438355               NaN    NaN  Helsinki          NaN        NaN
# 446178807               NaN    NaN       NaN          NaN        NaN
# 494775391               NaN    NaN       NaN          NaN        NaN
# 559139564               NaN    NaN  Helsinki          NaN        NaN
# 625576876               NaN    NaN  Helsinki          NaN        NaN
#
#                   ...         wheelchair  \
# 15242906          ...                NaN
# 17038654          ...                NaN
# 17039604          ...                NaN
# 23815666          ...                NaN
# 24904043          ...                NaN
# 26257345          ...                yes
# 26936530          ...                 no
# 28739860          ...                yes
# 31785988          ...            limited
# 34714712          ...                NaN
# 44490860          ...                NaN
# 44923563          ...                NaN
# 64297889          ...                NaN
# 88732590          ...                NaN
# 93983220          ...                NaN
# 115475357         ...                 no
# 115475359         ...                 no
# 156128272         ...                NaN
# 170507937         ...                NaN
# 332438355         ...                yes
# 446178807         ...                 no
# 494775391         ...                NaN
# 559139564         ...                NaN
# 625576876         ...                yes
#
#                                       wheelchair:description wholesale wifi  \
# 15242906                                                 NaN       NaN  NaN
# 17038654                                                 NaN       NaN  NaN
# 17039604                                                 NaN       NaN  NaN
# 23815666                                                 NaN       NaN  NaN
# 24904043                                                 NaN       NaN  NaN
# 26257345                                                 NaN       NaN  NaN
# 26936530                                                 NaN       NaN  NaN
# 28739860                                                 NaN       NaN  NaN
# 31785988                                                 NaN       NaN  NaN
# 34714712                                                 NaN       NaN  NaN
# 44490860                                                 NaN       NaN  NaN
# 44923563                                                 NaN       NaN  NaN
# 64297889                                                 NaN       NaN  NaN
# 88732590                                                 NaN       NaN  NaN
# 93983220                                                 NaN       NaN  NaN
# 115475357                                                NaN       NaN  NaN
# 115475359                                                NaN       NaN  NaN
# 156128272                                                NaN       NaN  NaN
# 170507937                                                NaN       NaN  NaN
# 332438355  Kelluva ja esteetön panoraamaravintola / Float...       NaN  NaN
# 446178807                                                NaN       NaN  NaN
# 494775391                                                NaN       NaN  NaN
# 559139564                                                NaN       NaN  NaN
# 625576876                                                NaN       NaN  NaN
#
#            wikidata              wikipedia wikipedia:en year year_on  \
# 15242906   Q6375016  fi:Katajanokan Kasino          NaN  NaN     NaN
# 17038654        NaN                    NaN          NaN  NaN     NaN
# 17039604        NaN                    NaN          NaN  NaN     NaN
# 23815666        NaN                    NaN          NaN  NaN     NaN
# 24904043        NaN                    NaN          NaN  NaN     NaN
# 26257345        NaN                    NaN          NaN  NaN     NaN
# 26936530        NaN                    NaN          NaN  NaN     NaN
# 28739860        NaN                    NaN          NaN  NaN     NaN
# 31785988        NaN                    NaN          NaN  NaN     NaN
# 34714712        NaN                    NaN          NaN  NaN     NaN
# 44490860        NaN                    NaN          NaN  NaN     NaN
# 44923563        NaN                    NaN          NaN  NaN     NaN
# 64297889        NaN                    NaN          NaN  NaN     NaN
# 88732590        NaN                    NaN          NaN  NaN     NaN
# 93983220        NaN                    NaN          NaN  NaN     NaN
# 115475357       NaN                    NaN          NaN  NaN     NaN
# 115475359       NaN                    NaN          NaN  NaN     NaN
# 156128272       NaN                    NaN          NaN  NaN     NaN
# 170507937       NaN                    NaN          NaN  NaN     NaN
# 332438355       NaN                    NaN          NaN  NaN     NaN
# 446178807       NaN                    NaN          NaN  NaN     NaN
# 494775391       NaN                    NaN          NaN  NaN     NaN
# 559139564       NaN                    NaN          NaN  NaN     NaN
# 625576876       NaN                    NaN          NaN  NaN     NaN
#
#           year_on:approximate
# 15242906                  NaN
# 17038654                  NaN
# 17039604                  NaN
# 23815666                  NaN
# 24904043                  NaN
# 26257345                  NaN
# 26936530                  NaN
# 28739860                  NaN
# 31785988                  NaN
# 34714712                  NaN
# 44490860                  NaN
# 44923563                  NaN
# 64297889                  NaN
# 88732590                  NaN
# 93983220                  NaN
# 115475357                 NaN
# 115475359                 NaN
# 156128272                 NaN
# 170507937                 NaN
# 332438355                 NaN
# 446178807                 NaN
# 494775391                 NaN
# 559139564                 NaN
# 625576876                 NaN
#
# [24 rows x 500 columns]

# %%
buildings['amenity'].unique()
# Out:
# array([nan, 'public_building', 'social_facility', 'theatre', 'clinic',
#        'school', 'place_of_worship', 'veterinary', 'kindergarten',
#        'car_wash', 'fast_food', 'fire_station', 'parking', 'leikkipuisto',
#        'restaurant', 'conference_centre', 'childcare', 'university',
#        'community_centre', 'preschool', 'shelter', 'ferry_terminal',
#        'library', 'embassy', 'car_rental', 'bank', 'doctors', 'recycling',
#        'fuel', 'bandstand', 'cafe', 'pub', 'music_school', 'crematorium',
#        'townhall', 'hospital', 'college', 'arts_centre', 'waste_disposal',
#        'nursing_home', 'fuel;car_wash', 'studio', 'exhibition_center',
#        'sauna', 'police', 'dentist', 'house_movals', 'shower', 'toilets',
#        'club', 'bicycle_parking', 'dressing_room', 'events_venue',
#        'changing_room', 'nightclub', 'ice_cream', 'courthouse',
#        'fuel;restaurant;car_wash', 'parliament', 'bbq', 'bar',
#        'waste_basket', 'swimming_pool'], dtype=object)

# %%
buildings[buildings['name'].notnull()]['name']
# Out:
# 4252923                               Uimastadion
# 4254163                            Hartwall Arena
# 4254310                                     Talli
# 4254311                                Vaunuhalli
# 4260855                 Arctech Helsinki Shipyard
# 4260901                      Hernesaaren jäähalli
# 4261024                               Fordin talo
# 4268713                     Talin jalkapallohalli
# 4432166                     Posti lajittelukeskus
# 5369288                               Digia Tower
# 5369294                                       ABB
# 6183586                             Liikuntamylly
# 6186794                                Megahertsi
# 6188230                      K-Supermarket Hertta
# 6188896                         Kauppakeskus Itis
# 6189301         Stoa (Itäkeskuksen monitoimitalo)
# 6189460                     Myllypuron Pallomylly
# 6267260                                  A-lehdet
# 6268325                                  Lanterna
# 6269033                              Iiris-keskus
# 6936362                                ED Station
# 6956686      Elintarviketurvallisuusvirasto Evira
# 7973628                            Janus 2 -halli
# 7973630                 Smash Center, päärakennus
# 8014585                             Säilytyshalli
# 8014589                              Ratakorjaamo
# 8033120                                   Ateneum
# 8034060                 Taivallahden Tenniskeskus
# 8034126                            Finlandia-talo
# 8034452                Mäkelänrinteen uintikeskus
#                              ...
# 563033904                              Sepän paja
# 564318409                          Metsä Fibre Oy
# 570006516                          Kääpäkuja 14 B
# 570654271      Hakaniemen kauppahallin väistötila
# 574521947                      McDonald's Kivikko
# 574607670                              Redi Sköne
# 574607671                              Redi Stadi
# 575082493                     K-Market Pikkupekka
# 575113932                     Uusi Lastensairaala
# 575539312                      Viikin nuorisotalo
# 576081601         Kruunuvuorenrannan koonta-asema
# 577974173                        trash facilities
# 578561510                        Varasto-osake.fi
# 579053784                     Hiilisuodatuslaitos
# 582249950                             Juskan talo
# 586488793                        Isotooppiyksikkö
# 596937289           Helsingin keskuskirjasto Oodi
# 614503215                             Myllypiha A
# 614503216                             Myllypiha B
# 614503219                             Myllypiha C
# 614503221                             Myllypiha D
# 614503223                             Myllypiha E
# 614503225                             Myllypiha H
# 614503227                             Myllypiha I
# 614503229                             Myllypiha J
# 614503230                             Myllypiha K
# 614503232                             Myllypiha F
# 614503235                             Myllypiha G
# 619185337          Ristipellontien liikuntakeskus
# 625576876                                   Löyly
# Name: name, Length: 1795, dtype: object

# %%
gc = Nominatim(user_agent="testing")

# %%
location = gc.geocode("Pohjolankatu 16, Helsinki", geometry='geojson')
location
# Out:
# Location(16, Pohjolankatu, Käpylä, Helsinki, Helsingin seutukunta, Uusimaa, Etelä-Suomi, Manner-Suomi, 00610, Suomi, (60.2149632, 24.94752825, 0.0))

# %%
bbox = ox.core.bbox_from_point(location)
bbox
# Out:
# (24.95654868407702, 24.93850780345498, 60.224857142180454, 60.2050693560969)

# %%
topleft = (bbox[0], bbox[2])
topright = (bbox[0], bbox[3])
bottomleft = (bbox[1], bbox[2])
bottomright = (bbox[1], bbox[3])
bbox_polygon = Polygon([topleft, topright, bottomright, bottomleft])
gdf = gp.GeoDataFrame(gp.GeoSeries(bbox_polygon), columns=['geometry'])
gdf
# Out:
#                                             geometry
# 0  POLYGON ((24.95654868407702 60.22485714218045,...

# %%
#intersections = gp.overlay(buildings, gdf, how='intersection')
#intersections.plot()

# %%
df = pd.read_csv("Pysakointivirheet.csv", encoding='ISO-8859-1')
df = df[df['Osoite'].notnull()]
df = df[df['Osoite'] != '-']
df
df['Osoite'] = df['Osoite'].apply(lambda x: x + ", Helsinki")
#df['coords'] = df['Osoite'].apply(lambda x: gc.geocode(x))
#df['coords'] = df['coords'].apply(lambda x: (x.latitude, x.longitude))
df['Osoite'].unique().shape
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,3,4,5,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (17203,)

# %%
df['coords']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coords'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4018c0ec503c> in <module>()
# ----> 1 df['coords']
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coords'
